# %% [markdown]
# # **1. Import Libraries**

# %%
#Install wget
# !pip3 install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=674edbf0c9a239bdba037c839af49f6e057c92846e4893ac05956cf18777f3f7
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...

# %%
#Import Libraries
import gzip
import shutil
import wget
import os
from pathlib import Path

# %%
#Function to extract files in .gzip
def gunzip_shutil(source_filepath, dest_filepath, block_size=65536):
    with gzip.open(source_filepath, 'rb') as s_file, \
            open(dest_filepath, 'wb') as d_file:
        shutil.copyfileobj(s_file, d_file, block_size)

# %% [markdown]
# # **2. Download Listings & Reviews Data from Insideairbnb.com**

# %%
#Define the date and files needed
dates = ["2026-01-08"]
files = ["listings.csv.gz", "reviews.csv.gz"]
remoteUrlbase = "http://data.insideairbnb.com/" + "canada/on/toronto/" # Ex: https://data.insideairbnb.com/canada/on/toronto/2026-01-16/data/listings.csv.gz
localUrlbase = "../2-data/input/Toronto_"

#Use Wget to create a  progress bar

# %%
#Use Pandas and import to dataframe
